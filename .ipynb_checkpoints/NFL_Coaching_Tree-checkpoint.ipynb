# %% [markdown]
# # NFL Coaching Tree
# #### This project focuses on tracing the lineage of NFL head coaching trees, mapping out how current and former coaches are connected through past coaching relationships. By analyzing these coaching trees, it becomes apparent how coaching philosophies, strategies, and networks have evolved and spread across the league over time. The goal is to visualize these connections and highlight influential coaching figures who have shaped the modern NFL. In addition, by viewing each staff's win total and potential awards received, we can get a better insight into how big of an impact a successful team played on the staff's individual success in the future

# %% [markdown]
# # First, we will load in all the necessary packages
# #### These packages will help us get a better understanding of the dataset and of all the variables that are at play.

# %%
# Imports 
import pandas as pd
import numpy as np
import pandasql as ps

# %% [markdown]
# ### We can load all datasets into a pandas library and view what's inside
# #### First is the coaches csv file. It contains information about a coach and each member on their staff alongside their role. Also contains info on how long each member was a part of the staff under the head coach alongside how the team's

# %%
hc = pd.read_csv('NFL_Coaches.csv')
ps.sqldf("select * from hc where Head_Coach = 'Jeff Fisher'")
# Out:
#     Head_Coach           Coach  weight group  group_count lrole   tW    tPyW  \
# 0  Jeff Fisher  Gregg Williams       6    DC            4    DC  173  168.13
# 1  Jeff Fisher    Jim Schwartz      10    DC            8    DC  173  168.13
# 2  Jeff Fisher    Mike Munchak      18   aOC           16   aOC  173  168.13
#
#    tg_hc  ftm  ...  fy_a  ly_a  TYr     nw  pyw500  above500  odo  cord  lodo  \
# 0    339  TEN  ...  1995  2000    6  1.000       0         1    2     1     2
# 1    339  TEN  ...  1999  2008   10  1.000       0         1    2     1     2
# 2    339  TEN  ...  1995  2010   16  1.125       0         1    1     0     1
#
#    lcord
# 0      1
# 1      1
# 2      0
#
# [3 rows x 23 columns]

# %% [markdown]
# #### Next, we can load in the wins csv file. It contains stats about a head coach's season with a tema such as wins/losses, total points scored for and against. In addition, it also contains whether or not a coach won/appeared in the superbowl that year, and if they received a coach of the year award

# %%
wins = pd.read_csv('wins.csv')
ps.sqldf("select * from wins where Tm = 'DET' order by Season desc")
# Out:
#     Season           Coach   Tm  Win  Loss  Tie   PF   PA  Total  fwk  ...  \
# 0     2022    Dan Campbell  DET    9     8    0  453  427     17    1  ...
# 1     2021    Dan Campbell  DET    3    13    1  325  467     17    1  ...
# 2     2020  Darrell Bevell  DET    1     4    0  125  191      5   13  ...
# 3     2020   Matt Patricia  DET    4     7    0  252  328     11    1  ...
# 4     2019   Matt Patricia  DET    3    12    1  341  423     16    1  ...
# ..     ...             ...  ...  ...   ...  ...  ...  ...    ...  ...  ...
# 57    1970     Joe Schmidt  DET   10     4    0  347  202     14    1  ...
# 58    1969     Joe Schmidt  DET    9     4    1  259  188     14    1  ...
# 59    1968     Joe Schmidt  DET    4     8    2  207  241     14    1  ...
# 60    1967     Joe Schmidt  DET    5     7    2  260  259     14    1  ...
# 61    1966    Harry Gilmer  DET    4     9    1  206  317     14    1  ...
#
#     yrs_hc  ftm  ltm    mpwpct  sb  sba  coy              name     pywins  \
# 0        3  MIA  DET  0.486228   0    0    0    Dan Campbell's   9.094395
# 1        3  MIA  DET  0.486065   0    0    0    Dan Campbell's   5.057843
# 2        2  DET  JAX  0.484773   0    0    0  Darrell Bevell's   4.556030
# 3        3  DET  DET  0.484773   0    0    0   Matt Patricia's   5.928144
# 4        3  DET  DET  0.480646   0    0    0   Matt Patricia's   6.375458
# ..     ...  ...  ...       ...  ..  ...  ...               ...        ...
# 57       6  DET  DET  0.474670   0    0    0     Joe Schmidt's  13.308313
# 58       6  DET  DET  0.505827   0    0    0     Joe Schmidt's  11.580485
# 59       6  DET  DET  0.481113   0    0    0     Joe Schmidt's   6.984563
# 60       6  DET  DET  0.501042   0    0    0     Joe Schmidt's   8.538815
# 61       1  DET  DET  0.487475   0    0    0    Harry Gilmer's   4.500399
#
#         awins
# 0    9.000000
# 1    3.500000
# 2    3.400000
# 3    6.181818
# 4    3.718750
# ..        ...
# 57  12.142857
# 58  11.535714
# 59   6.071429
# 60   7.285714
# 61   5.464286
#
# [62 rows x 34 columns]

# %% [markdown]
# #### We can join our coaches and win tables on the season in order to paint a full picture of what exactly each season entailed in terms of their overall performance, alongside who was on the team.

# %%
staff = ps.sqldf("""
WITH RECURSIVE year_sequence AS (
  -- Base case
  SELECT 
    Head_Coach,
    Coach,
    fy_a AS coaching_year,
    ly_a AS end_year,
    lrole
  FROM 
    hc
  
  UNION ALL
  
  -- Recursive case
  SELECT
    Head_Coach,
    Coach,
    coaching_year + 1,
    end_year,
    lrole
  FROM 
    year_sequence
  WHERE 
    coaching_year < end_year
)

SELECT 
  Head_Coach,
  Coach,
  coaching_year,
  lrole
FROM 
  year_sequence
ORDER BY 
  Head_Coach, Coach, coaching_year
""")
staff
# Out:
#        Head_Coach           Coach  coaching_year lrole
# 0       Adam Gase    Vance Joseph           2016    DC
# 1         Al Groh  Ken Whisenhunt           2000  aSTC
# 2         Al Groh      Mike Nolan           2000    DC
# 3         Al Groh     Todd Bowles           2000   aDC
# 4         Al Groh      Todd Haley           2000   aOC
# ...           ...             ...            ...   ...
# 2072  Weeb Ewbank   Walt Michaels           1967   aDC
# 2073  Weeb Ewbank   Walt Michaels           1968   aDC
# 2074  Weeb Ewbank   Walt Michaels           1969   aDC
# 2075  Weeb Ewbank   Walt Michaels           1970   aDC
# 2076  Weeb Ewbank   Walt Michaels           1971   aDC
#
# [2077 rows x 4 columns]

# %% [markdown]
# #### Now we can get an exact breakdown of a single head coach's staff for an entire specific season, and use this to better build our eventual coaching tree

# %%
final = ps.sqldf("select staff.coaching_year, staff.Head_Coach, staff.Coach, staff.lrole, wins.Tm, wins.Win, wins.Loss, wins.Tie from staff left join wins on staff.coaching_year=wins.Season and staff.Head_Coach = wins.Coach")
final
# Out:
#       coaching_year   Head_Coach           Coach lrole   Tm   Win  Loss  Tie
# 0              2016    Adam Gase    Vance Joseph    DC  MIA  10.0   6.0  0.0
# 1              2000      Al Groh  Ken Whisenhunt  aSTC  NYJ   9.0   7.0  0.0
# 2              2000      Al Groh      Mike Nolan    DC  NYJ   9.0   7.0  0.0
# 3              2000      Al Groh     Todd Bowles   aDC  NYJ   9.0   7.0  0.0
# 4              2000      Al Groh      Todd Haley   aOC  NYJ   9.0   7.0  0.0
# ...             ...          ...             ...   ...  ...   ...   ...  ...
# 2072           1967  Weeb Ewbank   Walt Michaels   aDC  NYJ   8.0   5.0  1.0
# 2073           1968  Weeb Ewbank   Walt Michaels   aDC  NYJ  11.0   3.0  0.0
# 2074           1969  Weeb Ewbank   Walt Michaels   aDC  NYJ  10.0   4.0  0.0
# 2075           1970  Weeb Ewbank   Walt Michaels   aDC  NYJ   4.0  10.0  0.0
# 2076           1971  Weeb Ewbank   Walt Michaels   aDC  NYJ   6.0   8.0  0.0
#
# [2077 rows x 8 columns]

# %%
ps.sqldf("select * from staff where Head_Coach = 'Jeff Fisher' order by coaching_year desc")
# Out:
#      Head_Coach           Coach  coaching_year lrole
# 0   Jeff Fisher    Mike Munchak           2010   aOC
# 1   Jeff Fisher    Mike Munchak           2009   aOC
# 2   Jeff Fisher    Jim Schwartz           2008    DC
# 3   Jeff Fisher    Mike Munchak           2008   aOC
# 4   Jeff Fisher    Jim Schwartz           2007    DC
# 5   Jeff Fisher    Mike Munchak           2007   aOC
# 6   Jeff Fisher    Jim Schwartz           2006    DC
# 7   Jeff Fisher    Mike Munchak           2006   aOC
# 8   Jeff Fisher    Jim Schwartz           2005    DC
# 9   Jeff Fisher    Mike Munchak           2005   aOC
# 10  Jeff Fisher    Jim Schwartz           2004    DC
# 11  Jeff Fisher    Mike Munchak           2004   aOC
# 12  Jeff Fisher    Jim Schwartz           2003    DC
# 13  Jeff Fisher    Mike Munchak           2003   aOC
# 14  Jeff Fisher    Jim Schwartz           2002    DC
# 15  Jeff Fisher    Mike Munchak           2002   aOC
# 16  Jeff Fisher    Jim Schwartz           2001    DC
# 17  Jeff Fisher    Mike Munchak           2001   aOC
# 18  Jeff Fisher  Gregg Williams           2000    DC
# 19  Jeff Fisher    Jim Schwartz           2000    DC
# 20  Jeff Fisher    Mike Munchak           2000   aOC
# 21  Jeff Fisher  Gregg Williams           1999    DC
# 22  Jeff Fisher    Jim Schwartz           1999    DC
# 23  Jeff Fisher    Mike Munchak           1999   aOC
# 24  Jeff Fisher  Gregg Williams           1998    DC
# 25  Jeff Fisher    Mike Munchak           1998   aOC
# 26  Jeff Fisher  Gregg Williams           1997    DC
# 27  Jeff Fisher    Mike Munchak           1997   aOC
# 28  Jeff Fisher  Gregg Williams           1996    DC
# 29  Jeff Fisher    Mike Munchak           1996   aOC
# 30  Jeff Fisher  Gregg Williams           1995    DC
# 31  Jeff Fisher    Mike Munchak           1995   aOC

# %%
ps.sqldf("select * from final where Tm = 'DET' order by coaching_year desc")
# Out:
#     coaching_year      Head_Coach                 Coach lrole   Tm   Win  \
# 0            2007   Rod Marinelli             Adam Gase   aOC  DET   7.0
# 1            2006   Rod Marinelli             Adam Gase   aOC  DET   3.0
# 2            2005  Steve Mariucci             Adam Gase   aOC  DET   4.0
# 3            2004  Steve Mariucci             Adam Gase   aOC  DET   6.0
# 4            2003  Steve Mariucci             Adam Gase   aOC  DET   5.0
# 5            2000      Bobby Ross              Jim Zorn   aOC  DET   5.0
# 6            2000    Gary Moeller              Jim Zorn   aOC  DET   4.0
# 7            1999      Bobby Ross          Gary Moeller   aDC  DET   8.0
# 8            1999      Bobby Ross              Jim Zorn   aOC  DET   8.0
# 9            1998      Bobby Ross          Gary Moeller   aDC  DET   5.0
# 10           1998      Bobby Ross              Jim Zorn   aOC  DET   5.0
# 11           1997      Bobby Ross          Gary Moeller   aDC  DET   9.0
# 12           1997      Bobby Ross         Marc Trestman   aOC  DET   9.0
# 13           1990    Wayne Fontes            June Jones   aOC  DET   6.0
# 14           1989    Wayne Fontes            June Jones   aOC  DET   7.0
# 15           1988   Darryl Rogers          Wayne Fontes    DC  DET   2.0
# 16           1987   Darryl Rogers          Wayne Fontes    DC  DET   4.0
# 17           1986   Darryl Rogers          Wayne Fontes    DC  DET   5.0
# 18           1985   Darryl Rogers          Wayne Fontes    DC  DET   7.0
# 19           1979     Monte Clark  Marty Schottenheimer   aDC  DET   2.0
# 20           1978     Monte Clark  Marty Schottenheimer   aDC  DET   7.0
# 21           1977  Tommy Hudspeth        Bill Belichick   aOC  DET   6.0
# 22           1976    Rick Forzano        Bill Belichick  aSTC  DET   1.0
# 23           1976    Rick Forzano       Jerry Glanville  aSTC  DET   1.0
# 24           1976    Rick Forzano             Joe Bugel   aOC  DET   1.0
# 25           1976  Tommy Hudspeth        Bill Belichick   aOC  DET   5.0
# 26           1976  Tommy Hudspeth       Jerry Glanville  aSTC  DET   5.0
# 27           1976  Tommy Hudspeth             Joe Bugel   aOC  DET   5.0
# 28           1975    Rick Forzano       Jerry Glanville  aSTC  DET   7.0
# 29           1975    Rick Forzano             Joe Bugel   aOC  DET   7.0
# 30           1975    Rick Forzano         Raymond Berry   aOC  DET   7.0
# 31           1974    Rick Forzano       Jerry Glanville  aSTC  DET   7.0
# 32           1974    Rick Forzano         Raymond Berry   aOC  DET   7.0
# 33           1973  Don McCafferty         Raymond Berry   aOC  DET   6.0
# 34           1973  Don McCafferty          Rick Forzano   aOC  DET   6.0
# 35           1972     Joe Schmidt            Chuck Knox   aOC  DET   8.0
# 36           1972     Joe Schmidt            John North   aOC  DET   8.0
# 37           1972     Joe Schmidt        Leeman Bennett   aOC  DET   8.0
# 38           1971     Joe Schmidt            Chuck Knox   aOC  DET   7.0
# 39           1971     Joe Schmidt            John North   aOC  DET   7.0
# 40           1970     Joe Schmidt            Chuck Knox   aOC  DET  10.0
# 41           1970     Joe Schmidt            John North   aOC  DET  10.0
# 42           1969     Joe Schmidt            Chuck Knox   aOC  DET   9.0
# 43           1969     Joe Schmidt            John North   aOC  DET   9.0
# 44           1968     Joe Schmidt            Chuck Knox   aOC  DET   4.0
# 45           1968     Joe Schmidt            John North   aOC  DET   4.0
# 46           1967     Joe Schmidt            Chuck Knox   aOC  DET   5.0
# 47           1967     Joe Schmidt            John North   aOC  DET   5.0
# 48           1966    Harry Gilmer           Joe Schmidt   aDC  DET   4.0
# 49           1966    Harry Gilmer            John North   aOC  DET   4.0
#
#     Loss  Tie
# 0    9.0  0.0
# 1   13.0  0.0
# 2    7.0  0.0
# 3   10.0  0.0
# 4   11.0  0.0
# 5    4.0  0.0
# 6    3.0  0.0
# 7    8.0  0.0
# 8    8.0  0.0
# 9   11.0  0.0
# 10  11.0  0.0
# 11   7.0  0.0
# 12   7.0  0.0
# 13  10.0  0.0
# 14   9.0  0.0
# 15   9.0  0.0
# 16  11.0  0.0
# 17  11.0  0.0
# 18   9.0  0.0
# 19  14.0  0.0
# 20   9.0  0.0
# 21   8.0  0.0
# 22   3.0  0.0
# 23   3.0  0.0
# 24   3.0  0.0
# 25   5.0  0.0
# 26   5.0  0.0
# 27   5.0  0.0
# 28   7.0  0.0
# 29   7.0  0.0
# 30   7.0  0.0
# 31   7.0  0.0
# 32   7.0  0.0
# 33   7.0  1.0
# 34   7.0  1.0
# 35   5.0  1.0
# 36   5.0  1.0
# 37   5.0  1.0
# 38   6.0  1.0
# 39   6.0  1.0
# 40   4.0  0.0
# 41   4.0  0.0
# 42   4.0  1.0
# 43   4.0  1.0
# 44   8.0  2.0
# 45   8.0  2.0
# 46   7.0  2.0
# 47   7.0  2.0
# 48   9.0  1.0
# 49   9.0  1.0
